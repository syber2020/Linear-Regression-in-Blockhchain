# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(5,105,5)
gas = [195984,320473,444959, 569448
,693935,818437,942923,1067437
,1191936,1324147,1448801,1573457
,1698111,1822781,1947435,2072116
,2198063,2323332,2448601,2573870]

# %%
# plt.figure(figsize=(10,7))
plt.ticklabel_format(useOffset=False, style='plain')

plt.plot(x, gas, marker = 'o', label = "get_y_hat : y = 37503* x + 104514 ")
plt.xlabel("Number of features", fontsize=14)
plt.ylabel("Gas Used in GWei", fontsize=14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.legend(fontsize=12)
plt.savefig("ropsten-gas-yhat.pdf", bbox_inches="tight")
plt.show()

# %%
x = np.arange(50,501,50)
plt.ticklabel_format(useOffset=False, style='plain')
get_ydiff=[2595000,5031150,7526600,10022200,12488000,14965705,17443410,19921115,22398820,24876525]

get_delta =[3278000,6439000,9604600,12770500,15936700,19100430,22265320,25430210,28595100,31759990]

get_deltab = [110200,141750,173350,205000,236650,268900,301300,332579,364396,396214]

plt.plot(x,get_ydiff,marker ='o' , label = "get_y_diff | y = 50759*x + 97720")

plt.plot(x,get_delta, marker ='o', label = "get_delta | y = 37611*x + 109578" )

plt.plot(x,get_deltab, marker = 'o', label ="get_deltab | y = 632*x + 45628" )
plt.ylabel("Gas used in GWei", fontsize=14)
plt.xlabel(" Number of samples ", fontsize=14)
plt.legend()
plt.savefig("ropsten-gas-other.pdf", bbox_inches="tight")
plt.show()
